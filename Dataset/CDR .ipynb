# %%
# !pip install faker

# %%
import pandas as pd
import networkx as nx
from faker import Faker
import random
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from networkx.algorithms.community import modularity
from networkx.algorithms.community import louvain_communities

# Initialize Faker
fake = Faker('en_IN')

# Number of records to generate
num_records = 1000
cdr_records = []

# Define the calling party pool and create communities
community_size = 10  # Number of members in each community
num_communities = 30  # Total number of communities
calling_party_pool = [''.join([str(random.randint(7, 9)) + ''.join([str(random.randint(0, 9)) for _ in range(9)])]) for _ in range(community_size * num_communities)]

# Define the communities explicitly
communities = [calling_party_pool[i * community_size: (i + 1) * community_size] for i in range(num_communities)]

# Assign IMEI and IMSI to each calling party
phone_to_imei_imsi = {
    phone: {
        "IMEI": ''.join([str(random.randint(0, 9)) for _ in range(15)]),
        "IMSI": ''.join([str(random.randint(0, 9)) for _ in range(15)]),
    }
    for phone in calling_party_pool
}

# Generate the call records
for community in communities:
    # Increase intra-community calls (more frequent calls within community)
    for calling_party in community:
        for _ in range(random.randint(20, 25)):  # Increase calls within community
            called_party = random.choice(community)
            while called_party == calling_party:
                called_party = random.choice(community)

            imei = phone_to_imei_imsi[calling_party]["IMEI"]
            imsi = phone_to_imei_imsi[calling_party]["IMSI"]
            call_type = random.choice(['Voice In', 'Voice Out', 'SMS In', 'SMS Out', 'Missed Call', 'Data Call'])
            call_date = fake.date_this_year()
            start_time = fake.time()

            if 'Voice' in call_type or 'Data' in call_type:
                duration = random.randint(60, 7200)  # 1 minute to 2 hours (more frequent, longer calls)
            else:
                duration = 0  # No duration for SMS calls

            start_time_obj = datetime.strptime(start_time, "%H:%M:%S")
            end_time_obj = start_time_obj + timedelta(seconds=duration)
            start_time = start_time_obj.strftime("%H:%M:%S")
            end_time = end_time_obj.strftime("%H:%M:%S") if duration > 0 else "N/A"

            cdr_records.append({
                'Calling Party': calling_party,
                'Called Party': called_party,
                'IMEI': imei,
                'IMSI': imsi,
                'Call Date': call_date,
                'Call Type': call_type,
                'Start Time': start_time,
                'End Time': end_time,
                'Duration (seconds)': duration
            })

    # Reduce inter-community calls (fewer calls between communities)
    for calling_party in community:
        for _ in range(random.randint(0, 1)):  # Very few calls between communities
            called_party = random.choice(calling_party_pool)
            while called_party == calling_party or called_party in community:
                called_party = random.choice(calling_party_pool)

            imei = phone_to_imei_imsi[calling_party]["IMEI"]
            imsi = phone_to_imei_imsi[calling_party]["IMSI"]
            call_type = random.choice(['Voice In', 'Voice Out', 'SMS In', 'SMS Out', 'Missed Call', 'Data Call'])
            call_date = fake.date_this_year()
            start_time = fake.time()

            if 'Voice' in call_type or 'Data' in call_type:
                duration = random.randint(60, 1800)  # 1 minute to 30 minutes
            else:
                duration = 0  # No duration for SMS calls

            start_time_obj = datetime.strptime(start_time, "%H:%M:%S")
            end_time_obj = start_time_obj + timedelta(seconds=duration)
            start_time = start_time_obj.strftime("%H:%M:%S")
            end_time = end_time_obj.strftime("%H:%M:%S") if duration > 0 else "N/A"

            cdr_records.append({
                'Calling Party': calling_party,
                'Called Party': called_party,
                'IMEI': imei,
                'IMSI': imsi,
                'Call Date': call_date,
                'Call Type': call_type,
                'Start Time': start_time,
                'End Time': end_time,
                'Duration (seconds)': duration
            })

# Convert the list of CDR records into a pandas DataFrame for easy viewing and manipulation
df = pd.DataFrame(cdr_records)

# Save the DataFrame to a CSV file
df.to_csv('CDR.csv', index=False)

# %%
import pandas as pd
import networkx as nx
from faker import Faker
import random
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from networkx.algorithms.community import modularity
from networkx.algorithms.community import louvain_communities

# Initialize Faker
fake = Faker('en_IN')

# Number of records to generate
num_records = 1000
cdr_records = []

# Define the calling party pool and create communities
community_size = 10  # Number of members in each community
num_communities = 30  # Total number of communities
calling_party_pool = [''.join([str(random.randint(7, 9)) + ''.join([str(random.randint(0, 9)) for _ in range(9)])]) for _ in range(community_size * num_communities)]

# Define the communities explicitly
communities = [calling_party_pool[i * community_size: (i + 1) * community_size] for i in range(num_communities)]

# Assign IMEI and IMSI to each calling party
phone_to_imei_imsi = {
    phone: {
        "IMEI": ''.join([str(random.randint(0, 9)) for _ in range(15)]),
        "IMSI": ''.join([str(random.randint(0, 9)) for _ in range(15)]),
    }
    for phone in calling_party_pool
}

# Generate the call records
for community in communities:
    # Increase intra-community calls (more frequent calls within community)
    for calling_party in community:
        for _ in range(random.randint(20, 25)):  # Increase calls within community
            called_party = random.choice(community)
            while called_party == calling_party:
                called_party = random.choice(community)

            imei = phone_to_imei_imsi[calling_party]["IMEI"]
            imsi = phone_to_imei_imsi[calling_party]["IMSI"]
            call_type = random.choice(['Voice In', 'Voice Out', 'SMS In', 'SMS Out', 'Missed Call', 'Data Call'])
            call_date = fake.date_this_year()
            start_time = fake.time()

            if 'Voice' in call_type or 'Data' in call_type:
                duration = random.randint(60, 7200)  # 1 minute to 2 hours (more frequent, longer calls)
            else:
                duration = 0  # No duration for SMS calls

            start_time_obj = datetime.strptime(start_time, "%H:%M:%S")
            end_time_obj = start_time_obj + timedelta(seconds=duration)
            start_time = start_time_obj.strftime("%H:%M:%S")
            end_time = end_time_obj.strftime("%H:%M:%S") if duration > 0 else "N/A"

            cdr_records.append({
                'Calling Party': calling_party,
                'Called Party': called_party,
                'IMEI': imei,
                'IMSI': imsi,
                'Call Date': call_date,
                'Call Type': call_type,
                'Start Time': start_time,
                'End Time': end_time,
                'Duration (seconds)': duration
            })

    # Reduce inter-community calls (fewer calls between communities)
    for calling_party in community:
        for _ in range(random.randint(0, 1)):  # Very few calls between communities
            called_party = random.choice(calling_party_pool)
            while called_party == calling_party or called_party in community:
                called_party = random.choice(calling_party_pool)

            imei = phone_to_imei_imsi[calling_party]["IMEI"]
            imsi = phone_to_imei_imsi[calling_party]["IMSI"]
            call_type = random.choice(['Voice In', 'Voice Out', 'SMS In', 'SMS Out', 'Missed Call', 'Data Call'])
            call_date = fake.date_this_year()
            start_time = fake.time()

            if 'Voice' in call_type or 'Data' in call_type:
                duration = random.randint(60, 1800)  # 1 minute to 30 minutes
            else:
                duration = 0  # No duration for SMS calls

            start_time_obj = datetime.strptime(start_time, "%H:%M:%S")
            end_time_obj = start_time_obj + timedelta(seconds=duration)
            start_time = start_time_obj.strftime("%H:%M:%S")
            end_time = end_time_obj.strftime("%H:%M:%S") if duration > 0 else "N/A"

            cdr_records.append({
                'Calling Party': calling_party,
                'Called Party': called_party,
                'IMEI': imei,
                'IMSI': imsi,
                'Call Date': call_date,
                'Call Type': call_type,
                'Start Time': start_time,
                'End Time': end_time,
                'Duration (seconds)': duration
            })

# Convert the list of CDR records into a pandas DataFrame for easy viewing and manipulation
df = pd.DataFrame(cdr_records)

# Save the DataFrame to a CSV file
df.to_csv('call_detail_records.csv', index=False)

# %%
import pandas as pd
import networkx as nx
from faker import Faker
import random
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from networkx.algorithms.community import modularity
from networkx.algorithms.community import louvain_communities

# Initialize Faker
fake = Faker('en_IN')

# Number of records to generate
num_records = 1000
cdr_records = []

# Define the calling party pool and create communities
community_size = 10  # Number of members in each community
num_communities = 30  # Total number of communities
calling_party_pool = [''.join([str(random.randint(7, 9)) + ''.join([str(random.randint(0, 9)) for _ in range(9)])]) for _ in range(community_size * num_communities)]

# Define the communities explicitly
communities = [calling_party_pool[i * community_size: (i + 1) * community_size] for i in range(num_communities)]

# Assign IMEI and IMSI to each calling party
phone_to_imei_imsi = {
    phone: {
        "IMEI": ''.join([str(random.randint(0, 9)) for _ in range(15)]),
        "IMSI": ''.join([str(random.randint(0, 9)) for _ in range(15)]),
    }
    for phone in calling_party_pool
}

# Generate the call records
for community in communities:
    # Increase intra-community calls (more frequent calls within community)
    for calling_party in community:
        for _ in range(random.randint(20, 25)):  # Increase calls within community
            called_party = random.choice(community)
            while called_party == calling_party:
                called_party = random.choice(community)

            imei = phone_to_imei_imsi[calling_party]["IMEI"]
            imsi = phone_to_imei_imsi[calling_party]["IMSI"]
            call_type = random.choice(['Voice In', 'Voice Out', 'SMS In', 'SMS Out', 'Missed Call', 'Data Call'])
            call_date = fake.date_this_year()
            start_time = fake.time()

            if 'Voice' in call_type or 'Data' in call_type:
                duration = random.randint(60, 7200)  # 1 minute to 2 hours (more frequent, longer calls)
            else:
                duration = 0  # No duration for SMS calls

            start_time_obj = datetime.strptime(start_time, "%H:%M:%S")
            end_time_obj = start_time_obj + timedelta(seconds=duration)
            start_time = start_time_obj.strftime("%H:%M:%S")
            end_time = end_time_obj.strftime("%H:%M:%S") if duration > 0 else "N/A"

            cdr_records.append({
                'Calling Party': calling_party,
                'Called Party': called_party,
                'IMEI': imei,
                'IMSI': imsi,
                'Call Date': call_date,
                'Call Type': call_type,
                'Start Time': start_time,
                'End Time': end_time,
                'Duration (seconds)': duration
            })

    # Reduce inter-community calls (fewer calls between communities)
    for calling_party in community:
        for _ in range(random.randint(0, 1)):  # Very few calls between communities
            called_party = random.choice(calling_party_pool)
            while called_party == calling_party or called_party in community:
                called_party = random.choice(calling_party_pool)

            imei = phone_to_imei_imsi[calling_party]["IMEI"]
            imsi = phone_to_imei_imsi[calling_party]["IMSI"]
            call_type = random.choice(['Voice In', 'Voice Out', 'SMS In', 'SMS Out', 'Missed Call', 'Data Call'])
            call_date = fake.date_this_year()
            start_time = fake.time()

            if 'Voice' in call_type or 'Data' in call_type:
                duration = random.randint(60, 1800)  # 1 minute to 30 minutes
            else:
                duration = 0  # No duration for SMS calls

            start_time_obj = datetime.strptime(start_time, "%H:%M:%S")
            end_time_obj = start_time_obj + timedelta(seconds=duration)
            start_time = start_time_obj.strftime("%H:%M:%S")
            end_time = end_time_obj.strftime("%H:%M:%S") if duration > 0 else "N/A"

            cdr_records.append({
                'Calling Party': calling_party,
                'Called Party': called_party,
                'IMEI': imei,
                'IMSI': imsi,
                'Call Date': call_date,
                'Call Type': call_type,
                'Start Time': start_time,
                'End Time': end_time,
                'Duration (seconds)': duration
            })

# Convert the list of CDR records into a pandas DataFrame for easy viewing and manipulation
df = pd.DataFrame(cdr_records)

# Save the DataFrame to a CSV file
df.to_csv('call_detail_records_improved.csv', index=False)

# %%
import pandas as pd
import networkx as nx
from faker import Faker
import random
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from networkx.algorithms.community import modularity
from networkx.algorithms.community import louvain_communities

# Initialize Faker
fake = Faker('en_IN')

# Number of records to generate
num_records = 1000
cdr_records = []

# Define the calling party pool and create communities
community_size = 10  # Number of members in each community
num_communities = 30  # Total number of communities
calling_party_pool = [''.join([str(random.randint(7, 9)) + ''.join([str(random.randint(0, 9)) for _ in range(9)])]) for _ in range(community_size * num_communities)]

# Define the communities explicitly
communities = [calling_party_pool[i * community_size: (i + 1) * community_size] for i in range(num_communities)]

# Assign IMEI and IMSI to each calling party
phone_to_imei_imsi = {
    phone: {
        "IMEI": ''.join([str(random.randint(0, 9)) for _ in range(15)]),
        "IMSI": ''.join([str(random.randint(0, 9)) for _ in range(15)]),
    }
    for phone in calling_party_pool
}

# Generate the call records
for community in communities:
    # Increase intra-community calls (more frequent calls within community)
    for calling_party in community:
        for _ in range(random.randint(20, 25)):  # Increase calls within community
            called_party = random.choice(community)
            while called_party == calling_party:
                called_party = random.choice(community)

            imei = phone_to_imei_imsi[calling_party]["IMEI"]
            imsi = phone_to_imei_imsi[calling_party]["IMSI"]
            call_type = random.choice(['Voice In', 'Voice Out', 'SMS In', 'SMS Out', 'Missed Call', 'Data Call'])
            call_date = fake.date_this_year()
            start_time = fake.time()

            if 'Voice' in call_type or 'Data' in call_type:
                duration = random.randint(60, 7200)  # 1 minute to 2 hours (more frequent, longer calls)
            else:
                duration = 0  # No duration for SMS calls

            start_time_obj = datetime.strptime(start_time, "%H:%M:%S")
            end_time_obj = start_time_obj + timedelta(seconds=duration)
            start_time = start_time_obj.strftime("%H:%M:%S")
            end_time = end_time_obj.strftime("%H:%M:%S") if duration > 0 else "N/A"

            cdr_records.append({
                'Calling Party': calling_party,
                'Called Party': called_party,
                'IMEI': imei,
                'IMSI': imsi,
                'Call Date': call_date,
                'Call Type': call_type,
                'Start Time': start_time,
                'End Time': end_time,
                'Duration (seconds)': duration
            })

        # Ensure mutual calls (the called party also calls back)
        called_party = random.choice(community)
        while called_party == calling_party:
            called_party = random.choice(community)

        # Add a reciprocal call
        imei = phone_to_imei_imsi[called_party]["IMEI"]
        imsi = phone_to_imei_imsi[called_party]["IMSI"]
        call_type = random.choice(['Voice In', 'Voice Out', 'SMS In', 'SMS Out', 'Missed Call', 'Data Call'])
        call_date = fake.date_this_year()
        start_time = fake.time()

        if 'Voice' in call_type or 'Data' in call_type:
            duration = random.randint(60, 7200)
        else:
            duration = 0

        start_time_obj = datetime.strptime(start_time, "%H:%M:%S")
        end_time_obj = start_time_obj + timedelta(seconds=duration)
        start_time = start_time_obj.strftime("%H:%M:%S")
        end_time = end_time_obj.strftime("%H:%M:%S") if duration > 0 else "N/A"

        cdr_records.append({
            'Calling Party': called_party,
            'Called Party': calling_party,
            'IMEI': imei,
            'IMSI': imsi,
            'Call Date': call_date,
            'Call Type': call_type,
            'Start Time': start_time,
            'End Time': end_time,
            'Duration (seconds)': duration
        })

    # Reduce inter-community calls (fewer calls between communities)
    for calling_party in community:
        for _ in range(random.randint(0, 1)):  # Very few calls between communities
            called_party = random.choice(calling_party_pool)
            while called_party == calling_party or called_party in community:
                called_party = random.choice(calling_party_pool)

            imei = phone_to_imei_imsi[calling_party]["IMEI"]
            imsi = phone_to_imei_imsi[calling_party]["IMSI"]
            call_type = random.choice(['Voice In', 'Voice Out', 'SMS In', 'SMS Out', 'Missed Call', 'Data Call'])
            call_date = fake.date_this_year()
            start_time = fake.time()

            if 'Voice' in call_type or 'Data' in call_type:
                duration = random.randint(60, 1800)  # 1 minute to 30 minutes
            else:
                duration = 0  # No duration for SMS calls

            start_time_obj = datetime.strptime(start_time, "%H:%M:%S")
            end_time_obj = start_time_obj + timedelta(seconds=duration)
            start_time = start_time_obj.strftime("%H:%M:%S")
            end_time = end_time_obj.strftime("%H:%M:%S") if duration > 0 else "N/A"

            cdr_records.append({
                'Calling Party': calling_party,
                'Called Party': called_party,
                'IMEI': imei,
                'IMSI': imsi,
                'Call Date': call_date,
                'Call Type': call_type,
                'Start Time': start_time,
                'End Time': end_time,
                'Duration (seconds)': duration
            })

# Convert the list of CDR records into a pandas DataFrame for easy viewing and manipulation
df = pd.DataFrame(cdr_records)

# Save the DataFrame to a CSV file
df.to_csv('CDR_2.csv', index=False)

# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import random
from datetime import datetime, timedelta
import itertools

# %%
# Load the data from CSV (make sure the CSV has the appropriate columns)
file_path = 'CDR_2.csv'  # Path to your CSV file
df = pd.read_csv(file_path)

# %%
import pandas as pd
import networkx as nx
from faker import Faker
import random
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from networkx.algorithms.community import modularity
from networkx.algorithms.community import louvain_communities

# Initialize Faker
fake = Faker('en_IN')

# Number of records to generate
num_records = 1000
cdr_records = []

# Define the calling party pool and create communities
community_size = 10  # Number of members in each community
num_communities = 30  # Total number of communities
calling_party_pool = [''.join([str(random.randint(7, 9)) + ''.join([str(random.randint(0, 9)) for _ in range(9)])]) for _ in range(community_size * num_communities)]

# Define the communities explicitly
communities = [calling_party_pool[i * community_size: (i + 1) * community_size] for i in range(num_communities)]

# Assign IMEI and IMSI to each calling party
phone_to_imei_imsi = {
    phone: {
        "IMEI": ''.join([str(random.randint(0, 9)) for _ in range(15)]),
        "IMSI": ''.join([str(random.randint(0, 9)) for _ in range(15)]),
    }
    for phone in calling_party_pool
}

# Generate the call records
for community in communities:
    # Increase intra-community calls (more frequent calls within community)
    for calling_party in community:
        for _ in range(random.randint(20, 25)):  # Increase calls within community
            called_party = random.choice(community)
            while called_party == calling_party:
                called_party = random.choice(community)

            imei = phone_to_imei_imsi[calling_party]["IMEI"]
            imsi = phone_to_imei_imsi[calling_party]["IMSI"]
            call_type = random.choice(['Voice In', 'Voice Out', 'SMS In', 'SMS Out', 'Missed Call', 'Data Call'])
            call_date = fake.date_this_year()
            start_time = fake.time()

            if 'Voice' in call_type or 'Data' in call_type:
                duration = random.randint(60, 7200)  # 1 minute to 2 hours (more frequent, longer calls)
            else:
                duration = 0  # No duration for SMS calls

            start_time_obj = datetime.strptime(start_time, "%H:%M:%S")
            end_time_obj = start_time_obj + timedelta(seconds=duration)
            start_time = start_time_obj.strftime("%H:%M:%S")
            end_time = end_time_obj.strftime("%H:%M:%S") if duration > 0 else "N/A"

            cdr_records.append({
                'Calling Party': calling_party,
                'Called Party': called_party,
                'IMEI': imei,
                'IMSI': imsi,
                'Call Date': call_date,
                'Call Type': call_type,
                'Start Time': start_time,
                'End Time': end_time,
                'Duration (seconds)': duration
            })

        # Ensure mutual calls (the called party also calls back)
        called_party = random.choice(community)
        while called_party == calling_party:
            called_party = random.choice(community)

        # Add a reciprocal call
        imei = phone_to_imei_imsi[called_party]["IMEI"]
        imsi = phone_to_imei_imsi[called_party]["IMSI"]
        call_type = random.choice(['Voice In', 'Voice Out', 'SMS In', 'SMS Out', 'Missed Call', 'Data Call'])
        call_date = fake.date_this_year()
        start_time = fake.time()

        if 'Voice' in call_type or 'Data' in call_type:
            duration = random.randint(60, 7200)
        else:
            duration = 0

        start_time_obj = datetime.strptime(start_time, "%H:%M:%S")
        end_time_obj = start_time_obj + timedelta(seconds=duration)
        start_time = start_time_obj.strftime("%H:%M:%S")
        end_time = end_time_obj.strftime("%H:%M:%S") if duration > 0 else "N/A"

        cdr_records.append({
            'Calling Party': called_party,
            'Called Party': calling_party,
            'IMEI': imei,
            'IMSI': imsi,
            'Call Date': call_date,
            'Call Type': call_type,
            'Start Time': start_time,
            'End Time': end_time,
            'Duration (seconds)': duration
        })

    # Reduce inter-community calls (fewer calls between communities)
    for calling_party in community:
        for _ in range(random.randint(0, 1)):  # Very few calls between communities
            called_party = random.choice(calling_party_pool)
            while called_party == calling_party or called_party in community:
                called_party = random.choice(calling_party_pool)

            imei = phone_to_imei_imsi[calling_party]["IMEI"]
            imsi = phone_to_imei_imsi[calling_party]["IMSI"]
            call_type = random.choice(['Voice In', 'Voice Out', 'SMS In', 'SMS Out', 'Missed Call', 'Data Call'])
            call_date = fake.date_this_year()
            start_time = fake.time()

            if 'Voice' in call_type or 'Data' in call_type:
                duration = random.randint(60, 1800)  # 1 minute to 30 minutes
            else:
                duration = 0  # No duration for SMS calls

            start_time_obj = datetime.strptime(start_time, "%H:%M:%S")
            end_time_obj = start_time_obj + timedelta(seconds=duration)
            start_time = start_time_obj.strftime("%H:%M:%S")
            end_time = end_time_obj.strftime("%H:%M:%S") if duration > 0 else "N/A"

            cdr_records.append({
                'Calling Party': calling_party,
                'Called Party': called_party,
                'IMEI': imei,
                'IMSI': imsi,
                'Call Date': call_date,
                'Call Type': call_type,
                'Start Time': start_time,
                'End Time': end_time,
                'Duration (seconds)': duration
            })

# Convert the list of CDR records into a pandas DataFrame for easy viewing and manipulation
df = pd.DataFrame(cdr_records)

# Save the DataFrame to a CSV file
df.to_csv('CDR3.csv', index=False)

# %%
import pandas as pd
import networkx as nx
from faker import Faker
import random
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from networkx.algorithms.community import modularity
from networkx.algorithms.community import louvain_communities

# Initialize Faker
fake = Faker('en_IN')

# Number of records to generate
num_records = 1000
cdr_records = []

# Define the calling party pool and create communities with variable sizes
min_community_size = 5  # Minimum number of members in each community
max_community_size = 15  # Maximum number of members in each community
num_communities = 30  # Total number of communities

# Create a pool of phone numbers
calling_party_pool = [''.join([str(random.randint(7, 9)) + ''.join([str(random.randint(0, 9)) for _ in range(9)])]) for _ in range(num_communities * max_community_size)]

# Define the communities explicitly with variable sizes
communities = []
remaining_pool = calling_party_pool[:]
for _ in range(num_communities):
    # Randomly assign community size between min_community_size and max_community_size
    community_size = random.randint(min_community_size, max_community_size)
    community = random.sample(remaining_pool, community_size)
    communities.append(community)
    remaining_pool = [x for x in remaining_pool if x not in community]

# Assign IMEI and IMSI to each calling party
phone_to_imei_imsi = {
    phone: {
        "IMEI": ''.join([str(random.randint(0, 9)) for _ in range(15)]),
        "IMSI": ''.join([str(random.randint(0, 9)) for _ in range(15)]),
    }
    for phone in calling_party_pool
}

# Generate the call records
for community in communities:
    # Increase intra-community calls (more frequent calls within community)
    for calling_party in community:
        for _ in range(random.randint(25, 30)):  # Increased calls within community
            called_party = random.choice(community)
            while called_party == calling_party:
                called_party = random.choice(community)

            imei = phone_to_imei_imsi[calling_party]["IMEI"]
            imsi = phone_to_imei_imsi[calling_party]["IMSI"]
            call_type = random.choice(['Voice In', 'Voice Out', 'SMS In', 'SMS Out', 'Missed Call', 'Data Call'])
            call_date = fake.date_this_year()
            start_time = fake.time()

            if 'Voice' in call_type or 'Data' in call_type:
                duration = random.randint(60, 7200)  # 1 minute to 2 hours (more frequent, longer calls)
            else:
                duration = 0  # No duration for SMS calls

            start_time_obj = datetime.strptime(start_time, "%H:%M:%S")
            end_time_obj = start_time_obj + timedelta(seconds=duration)
            start_time = start_time_obj.strftime("%H:%M:%S")
            end_time = end_time_obj.strftime("%H:%M:%S") if duration > 0 else "N/A"

            cdr_records.append({
                'Calling Party': calling_party,
                'Called Party': called_party,
                'IMEI': imei,
                'IMSI': imsi,
                'Call Date': call_date,
                'Call Type': call_type,
                'Start Time': start_time,
                'End Time': end_time,
                'Duration (seconds)': duration
            })

    # Reduce inter-community calls (fewer calls between communities)
    for calling_party in community:
        for _ in range(random.randint(0, 1)):  # Very few calls between communities
            called_party = random.choice(calling_party_pool)
            while called_party == calling_party or called_party in community:
                called_party = random.choice(calling_party_pool)

            imei = phone_to_imei_imsi[calling_party]["IMEI"]
            imsi = phone_to_imei_imsi[calling_party]["IMSI"]
            call_type = random.choice(['Voice In', 'Voice Out', 'SMS In', 'SMS Out', 'Missed Call', 'Data Call'])
            call_date = fake.date_this_year()
            start_time = fake.time()

            if 'Voice' in call_type or 'Data' in call_type:
                duration = random.randint(60, 1800)  # 1 minute to 30 minutes
            else:
                duration = 0  # No duration for SMS calls

            start_time_obj = datetime.strptime(start_time, "%H:%M:%S")
            end_time_obj = start_time_obj + timedelta(seconds=duration)
            start_time = start_time_obj.strftime("%H:%M:%S")
            end_time = end_time_obj.strftime("%H:%M:%S") if duration > 0 else "N/A"

            cdr_records.append({
                'Calling Party': calling_party,
                'Called Party': called_party,
                'IMEI': imei,
                'IMSI': imsi,
                'Call Date': call_date,
                'Call Type': call_type,
                'Start Time': start_time,
                'End Time': end_time,
                'Duration (seconds)': duration
            })

# Convert the list of CDR records into a pandas DataFrame for easy viewing and manipulation
df = pd.DataFrame(cdr_records)

# Save the DataFrame to a CSV file
df.to_csv('CDR4.csv', index=False)

# %%
import pandas as pd
import networkx as nx
from faker import Faker
import random
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from networkx.algorithms.community import modularity
from networkx.algorithms.community import louvain_communities

# Initialize Faker
fake = Faker('en_IN')

# Number of records to generate
num_records = 1000
cdr_records = []

# Define the calling party pool and create communities with variable sizes
min_community_size = 8  # Minimum number of members in each community
max_community_size = 12  # Maximum number of members in each community
num_communities = 20  # Total number of communities

# Create a pool of phone numbers
calling_party_pool = [''.join([str(random.randint(7, 9)) + ''.join([str(random.randint(0, 9)) for _ in range(9)])]) for _ in range(num_communities * max_community_size)]

# Define the communities explicitly with variable sizes
communities = []
remaining_pool = calling_party_pool[:]
for _ in range(num_communities):
    # Randomly assign community size between min_community_size and max_community_size
    community_size = random.randint(min_community_size, max_community_size)
    community = random.sample(remaining_pool, community_size)
    communities.append(community)
    remaining_pool = [x for x in remaining_pool if x not in community]

# Assign IMEI and IMSI to each calling party
phone_to_imei_imsi = {
    phone: {
        "IMEI": ''.join([str(random.randint(0, 9)) for _ in range(15)]),
        "IMSI": ''.join([str(random.randint(0, 9)) for _ in range(15)]),
    }
    for phone in calling_party_pool
}

# Generate the call records
for community in communities:
    # Increase intra-community calls (more frequent calls within community)
    for calling_party in community:
        for _ in range(random.randint(20, 25)):  # Increased calls within community
            called_party = random.choice(community)
            while called_party == calling_party:
                called_party = random.choice(community)

            imei = phone_to_imei_imsi[calling_party]["IMEI"]
            imsi = phone_to_imei_imsi[calling_party]["IMSI"]
            call_type = random.choice(['Voice In', 'Voice Out', 'SMS In', 'SMS Out', 'Missed Call', 'Data Call'])
            call_date = fake.date_this_year()
            start_time = fake.time()

            if 'Voice' in call_type or 'Data' in call_type:
                duration = random.randint(60, 7200)  # 1 minute to 2 hours (more frequent, longer calls)
            else:
                duration = 0  # No duration for SMS calls

            start_time_obj = datetime.strptime(start_time, "%H:%M:%S")
            end_time_obj = start_time_obj + timedelta(seconds=duration)
            start_time = start_time_obj.strftime("%H:%M:%S")
            end_time = end_time_obj.strftime("%H:%M:%S") if duration > 0 else "N/A"

            cdr_records.append({
                'Calling Party': calling_party,
                'Called Party': called_party,
                'IMEI': imei,
                'IMSI': imsi,
                'Call Date': call_date,
                'Call Type': call_type,
                'Start Time': start_time,
                'End Time': end_time,
                'Duration (seconds)': duration
            })

    # Reduce inter-community calls (fewer calls between communities)
    for calling_party in community:
        for _ in range(random.randint(0, 1)):  # Very few calls between communities
            called_party = random.choice(calling_party_pool)
            while called_party == calling_party or called_party in community:
                called_party = random.choice(calling_party_pool)

            imei = phone_to_imei_imsi[calling_party]["IMEI"]
            imsi = phone_to_imei_imsi[calling_party]["IMSI"]
            call_type = random.choice(['Voice In', 'Voice Out', 'SMS In', 'SMS Out', 'Missed Call', 'Data Call'])
            call_date = fake.date_this_year()
            start_time = fake.time()

            if 'Voice' in call_type or 'Data' in call_type:
                duration = random.randint(60, 2000)  # 1 minute to 30 minutes
            else:
                duration = 0  # No duration for SMS calls

            start_time_obj = datetime.strptime(start_time, "%H:%M:%S")
            end_time_obj = start_time_obj + timedelta(seconds=duration)
            start_time = start_time_obj.strftime("%H:%M:%S")
            end_time = end_time_obj.strftime("%H:%M:%S") if duration > 0 else "N/A"

            cdr_records.append({
                'Calling Party': calling_party,
                'Called Party': called_party,
                'IMEI': imei,
                'IMSI': imsi,
                'Call Date': call_date,
                'Call Type': call_type,
                'Start Time': start_time,
                'End Time': end_time,
                'Duration (seconds)': duration
            })

# Convert the list of CDR records into a pandas DataFrame for easy viewing and manipulation
df = pd.DataFrame(cdr_records)

# Save the DataFrame to a CSV file
df.to_csv('CDR5', index=False)

# %%
import pandas as pd
import networkx as nx
from faker import Faker
import random
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from networkx.algorithms.community import modularity
from networkx.algorithms.community import louvain_communities

# Initialize Faker
fake = Faker('en_IN')

# Number of records to generate
num_records = 1800
cdr_records = []

# Define the calling party pool and create communities with variable sizes
min_community_size = 5  # Minimum number of members in each community
max_community_size = 15  # Maximum number of members in each community
num_communities = 30  # Total number of communities

# Create a pool of phone numbers
calling_party_pool = [''.join([str(random.randint(7, 9)) + ''.join([str(random.randint(0, 9)) for _ in range(9)])]) for _ in range(num_communities * max_community_size)]

# Define the communities explicitly with variable sizes
communities = []
remaining_pool = calling_party_pool[:]
for _ in range(num_communities):
    # Randomly assign community size between min_community_size and max_community_size
    community_size = random.randint(min_community_size, max_community_size)
    community = random.sample(remaining_pool, community_size)
    communities.append(community)
    remaining_pool = [x for x in remaining_pool if x not in community]

# Assign IMEI and IMSI to each calling party
phone_to_imei_imsi = {
    phone: {
        "IMEI": ''.join([str(random.randint(0, 9)) for _ in range(15)]),
        "IMSI": ''.join([str(random.randint(0, 9)) for _ in range(15)]),
    }
    for phone in calling_party_pool
}

# Generate the call records
for community in communities:
    # Increase intra-community calls (more frequent calls within community)
    for calling_party in community:
        for _ in range(random.randint(25, 30)):  # Increased calls within community
            called_party = random.choice(community)
            while called_party == calling_party:
                called_party = random.choice(community)

            imei = phone_to_imei_imsi[calling_party]["IMEI"]
            imsi = phone_to_imei_imsi[calling_party]["IMSI"]
            call_type = random.choice(['Voice In', 'Voice Out', 'SMS In', 'SMS Out', 'Missed Call', 'Data Call'])
            call_date = fake.date_this_year()
            start_time = fake.time()

            if 'Voice' in call_type or 'Data' in call_type:
                duration = random.randint(60, 7200)  # 1 minute to 2 hours (more frequent, longer calls)
            else:
                duration = 0  # No duration for SMS calls

            start_time_obj = datetime.strptime(start_time, "%H:%M:%S")
            end_time_obj = start_time_obj + timedelta(seconds=duration)
            start_time = start_time_obj.strftime("%H:%M:%S")
            end_time = end_time_obj.strftime("%H:%M:%S") if duration > 0 else "N/A"

            cdr_records.append({
                'Calling Party': calling_party,
                'Called Party': called_party,
                'IMEI': imei,
                'IMSI': imsi,
                'Call Date': call_date,
                'Call Type': call_type,
                'Start Time': start_time,
                'End Time': end_time,
                'Duration (seconds)': duration
            })

        # Ensure mutual calls (the called party also calls back)
        called_party = random.choice(community)
        while called_party == calling_party:
            called_party = random.choice(community)

        # Add a reciprocal call
        imei = phone_to_imei_imsi[called_party]["IMEI"]
        imsi = phone_to_imei_imsi[called_party]["IMSI"]
        call_type = random.choice(['Voice In', 'Voice Out', 'SMS In', 'SMS Out', 'Missed Call', 'Data Call'])
        call_date = fake.date_this_year()
        start_time = fake.time()

        if 'Voice' in call_type or 'Data' in call_type:
            duration = random.randint(60, 7200)
        else:
            duration = 0

        start_time_obj = datetime.strptime(start_time, "%H:%M:%S")
        end_time_obj = start_time_obj + timedelta(seconds=duration)
        start_time = start_time_obj.strftime("%H:%M:%S")
        end_time = end_time_obj.strftime("%H:%M:%S") if duration > 0 else "N/A"

        cdr_records.append({
            'Calling Party': called_party,
            'Called Party': calling_party,
            'IMEI': imei,
            'IMSI': imsi,
            'Call Date': call_date,
            'Call Type': call_type,
            'Start Time': start_time,
            'End Time': end_time,
            'Duration (seconds)': duration
        })

    # Reduce inter-community calls (fewer calls between communities)
    for calling_party in community:
        for _ in range(random.randint(0, 1)):  # Very few calls between communities
            called_party = random.choice(calling_party_pool)
            while called_party == calling_party or called_party in community:
                called_party = random.choice(calling_party_pool)

            imei = phone_to_imei_imsi[calling_party]["IMEI"]
            imsi = phone_to_imei_imsi[calling_party]["IMSI"]
            call_type = random.choice(['Voice In', 'Voice Out', 'SMS In', 'SMS Out', 'Missed Call', 'Data Call'])
            call_date = fake.date_this_year()
            start_time = fake.time()

            if 'Voice' in call_type or 'Data' in call_type:
                duration = random.randint(60, 1800)  # 1 minute to 30 minutes
            else:
                duration = 0  # No duration for SMS calls

            start_time_obj = datetime.strptime(start_time, "%H:%M:%S")
            end_time_obj = start_time_obj + timedelta(seconds=duration)
            start_time = start_time_obj.strftime("%H:%M:%S")
            end_time = end_time_obj.strftime("%H:%M:%S") if duration > 0 else "N/A"

            cdr_records.append({
                'Calling Party': calling_party,
                'Called Party': called_party,
                'IMEI': imei,
                'IMSI': imsi,
                'Call Date': call_date,
                'Call Type': call_type,
                'Start Time': start_time,
                'End Time': end_time,
                'Duration (seconds)': duration
            })

# Convert the list of CDR records into a pandas DataFrame for easy viewing and manipulation
df = pd.DataFrame(cdr_records)

# Save the DataFrame to a CSV file
df.to_csv('CDR4.csv', index=False)
